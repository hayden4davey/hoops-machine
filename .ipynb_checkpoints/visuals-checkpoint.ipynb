# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
bb_df = pd.read_csv("Resources/CleanHoopsData.csv")
bb_df.head()
# Out:
#      Year                Player Pos   Age  Height  Weight   Tm     G     MP  \
# 0  1979.0  Kareem Abdul-Jabbar*   C  31.0   218.0   102.0  LAL  80.0  39.46
# 1  1979.0         Tom Abernethy  PF  24.0   201.0    99.0  GSW  70.0  17.41
# 2  1979.0           Alvan Adams   C  24.0   206.0    95.0  PHO  77.0  30.70
# 3  1979.0          Lucius Allen  PG  31.0   188.0    79.0  KCK  31.0  13.32
# 4  1979.0          Kim Anderson  SF  23.0   201.0    90.0  POR  21.0  10.67
#
#      PTS  ...    FG%   3P  3PA  3P%    2P    2PA    2P%    FT   FTA    FT%
# 0  23.79  ...  0.577  0.0  0.0  0.0  9.71  16.84  0.577  4.36  5.92  0.736
# 1   6.03  ...  0.515  0.0  0.0  0.0  2.51   4.89  0.515  1.00  1.34  0.745
# 2  17.78  ...  0.530  0.0  0.0  0.0  7.39  13.94  0.530  3.00  3.75  0.799
# 3   5.06  ...  0.397  0.0  0.0  0.0  2.23   5.61  0.397  0.61  1.06  0.576
# 4   3.00  ...  0.312  0.0  0.0  0.0  1.14   3.67  0.312  0.71  1.33  0.536
#
# [5 rows x 43 columns]

# %%
bb_df['Pos'] = bb_df['Pos'].map({'PG':1, 'SG':2, 'SF':3, 'PF':4,'C':5})

# %%
plt.scatter(bb_df['Pos'], bb_df['Height'], edgecolors='black', alpha=0.5)
plt.grid(axis='both', which='major')
plt.title('Position Played by Height')
plt.xlabel('Position')
plt.ylabel('Height(cm)')
plt.xticks(np.arange(0, 6, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x12963138550>,
# ...
#  <a list of 6 Text xticklabel objects>)

# %%
plt.savefig('static/images/HeightVis.png')

# %%
bb_df['BMI'] = bb_df['Weight'] / ((bb_df['Height']/100)*(bb_df['Height']/100))

# %%
plt.scatter(bb_df['Pos'], bb_df['BMI'], edgecolors='black', alpha=0.5)
plt.grid(axis='both', which='major')
plt.title('Position Played by BMI')
plt.xlabel('Position')
plt.ylabel('Body Mass Index')
plt.xticks(np.arange(0, 6, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x129634f4828>,
# ...
#  <a list of 6 Text xticklabel objects>)

# %%
plt.savefig('static/images/BMIVis.png')

# %%
plt.scatter(bb_df['Pos'], bb_df['AST%'], edgecolors='black', alpha=0.5)
plt.grid(axis='both', which='major')
plt.title('Assist Percentage by Player Position')
plt.xlabel('Position')
plt.ylabel('Assist Percentage')
plt.xticks(np.arange(0, 6, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x1296353ba90>,
# ...
#  <a list of 6 Text xticklabel objects>)

# %%
plt.savefig('static/images/AstPerVis.png')

# %%
plt.scatter(bb_df['Pos'], bb_df['AST'], edgecolors='black', alpha=0.5)
plt.grid(axis='both', which='major')
plt.title('Assists by Player Position')
plt.xlabel('Position')
plt.ylabel('Assists per Game')
plt.xticks(np.arange(0, 6, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x129635c42e8>,
# ...
#  <a list of 6 Text xticklabel objects>)

# %%
plt.savefig('static/images/AstVis.png')

# %%
plt.scatter(bb_df['Pos'], bb_df['TRB'], edgecolors='black', alpha=0.5)
plt.grid(axis='both', which='major')
plt.title('Rebounds by Player Position')
plt.xlabel('Position')
plt.ylabel('Rebounds per Game')
plt.xticks(np.arange(0, 6, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x12963425cf8>,
# ...
#  <a list of 6 Text xticklabel objects>)

# %%
plt.savefig('static/images/RebVis.png')
