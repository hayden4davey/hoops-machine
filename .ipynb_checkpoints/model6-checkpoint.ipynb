# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
bb_df = pd.read_csv("Resources/CleanHoopsData.csv")
bb_df.head()
# Out:
#      Year                Player Pos   Age  Height  Weight   Tm     G     MP  \
# 0  1979.0  Kareem Abdul-Jabbar*   C  31.0   218.0   102.0  LAL  80.0  39.46
# 1  1979.0         Tom Abernethy  PF  24.0   201.0    99.0  GSW  70.0  17.41
# 2  1979.0           Alvan Adams   C  24.0   206.0    95.0  PHO  77.0  30.70
# 3  1979.0          Lucius Allen  PG  31.0   188.0    79.0  KCK  31.0  13.32
# 4  1979.0          Kim Anderson  SF  23.0   201.0    90.0  POR  21.0  10.67
#
#      PTS  ...    FG%   3P  3PA  3P%    2P    2PA    2P%    FT   FTA    FT%
# 0  23.79  ...  0.577  0.0  0.0  0.0  9.71  16.84  0.577  4.36  5.92  0.736
# 1   6.03  ...  0.515  0.0  0.0  0.0  2.51   4.89  0.515  1.00  1.34  0.745
# 2  17.78  ...  0.530  0.0  0.0  0.0  7.39  13.94  0.530  3.00  3.75  0.799
# 3   5.06  ...  0.397  0.0  0.0  0.0  2.23   5.61  0.397  0.61  1.06  0.576
# 4   3.00  ...  0.312  0.0  0.0  0.0  1.14   3.67  0.312  0.71  1.33  0.536
#
# [5 rows x 43 columns]

# %%
positions = bb_df['Pos'].map({'PG':1, 'SG':2, 'SF':3, 'PF':4,'C':5})

# %%
data = bb_df.drop(['Tm','Player','Pos', 'Height','Weight'], axis=1)
feature_names = data.columns
data.head()
# Out:
#      Year   Age     G     MP    PTS   AST    TRB   ORB    DRB   STL  ...  \
# 0  1979.0  31.0  80.0  39.46  23.79  5.39  12.81  2.59  10.22  0.95  ...
# 1  1979.0  24.0  70.0  17.41   6.03  1.13   3.09  1.06   2.03  0.56  ...
# 2  1979.0  24.0  77.0  30.70  17.78  4.68   9.16  2.86   6.30  1.43  ...
# 3  1979.0  31.0  31.0  13.32   5.06  1.42   1.48  0.45   1.03  0.68  ...
# 4  1979.0  23.0  21.0  10.67   3.00  0.71   2.14  0.81   1.33  0.19  ...
#
#      FG%   3P  3PA  3P%    2P    2PA    2P%    FT   FTA    FT%
# 0  0.577  0.0  0.0  0.0  9.71  16.84  0.577  4.36  5.92  0.736
# 1  0.515  0.0  0.0  0.0  2.51   4.89  0.515  1.00  1.34  0.745
# 2  0.530  0.0  0.0  0.0  7.39  13.94  0.530  3.00  3.75  0.799
# 3  0.397  0.0  0.0  0.0  2.23   5.61  0.397  0.61  1.06  0.576
# 4  0.312  0.0  0.0  0.0  1.14   3.67  0.312  0.71  1.33  0.536
#
# [5 rows x 38 columns]

# %%
data['Year'] = data['Year'] - 1978
data.head()
# Out:
#    Year   Age     G     MP    PTS   AST    TRB   ORB    DRB   STL  ...    FG%  \
# 0   1.0  31.0  80.0  39.46  23.79  5.39  12.81  2.59  10.22  0.95  ...  0.577
# 1   1.0  24.0  70.0  17.41   6.03  1.13   3.09  1.06   2.03  0.56  ...  0.515
# 2   1.0  24.0  77.0  30.70  17.78  4.68   9.16  2.86   6.30  1.43  ...  0.530
# 3   1.0  31.0  31.0  13.32   5.06  1.42   1.48  0.45   1.03  0.68  ...  0.397
# 4   1.0  23.0  21.0  10.67   3.00  0.71   2.14  0.81   1.33  0.19  ...  0.312
#
#     3P  3PA  3P%    2P    2PA    2P%    FT   FTA    FT%
# 0  0.0  0.0  0.0  9.71  16.84  0.577  4.36  5.92  0.736
# 1  0.0  0.0  0.0  2.51   4.89  0.515  1.00  1.34  0.745
# 2  0.0  0.0  0.0  7.39  13.94  0.530  3.00  3.75  0.799
# 3  0.0  0.0  0.0  2.23   5.61  0.397  0.61  1.06  0.576
# 4  0.0  0.0  0.0  1.14   3.67  0.312  0.71  1.33  0.536
#
# [5 rows x 38 columns]

# %%
from sklearn.cluster import MiniBatchKMeans
kmeans = MiniBatchKMeans(n_clusters=5)

# %%
kmeans.fit(data)
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=100, max_no_improvement=10,
#                 n_clusters=5, n_init=3, random_state=None,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
predicted_clusters = kmeans.predict(data)

# %%
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
label.size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a05b7631cc8e> in <module>
# ----> 1 label.size
#
# NameError: name 'label' is not defined
